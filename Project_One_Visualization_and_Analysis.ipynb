# %% [markdown]
# # PART 2: Data Visualization and Analysis

# %%
#!python -m pip install -U pip
#!python -m pip install -U matplotlib
#!python -m pip install -U sklearn
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-0.23.2-cp36-cp36m-macosx_10_9_x86_64.whl (7.2 MB)
#      |████████████████████████████████| 7.2 MB 5.1 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /Users/madhavsrivastava/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages (from scikit-learn->sklearn) (1.19.2)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Collecting joblib>=0.11
#   Downloading joblib-0.17.0-py3-none-any.whl (301 kB)
#      |████████████████████████████████| 301 kB 9.5 MB/s eta 0:00:01
# Collecting scipy>=0.19.1
#   Downloading scipy-1.5.4-cp36-cp36m-macosx_10_9_x86_64.whl (28.8 MB)
#      |████████████████████████████████| 28.8 MB 799 kB/s eta 0:00:01
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=ce18cc56e81f391c36c7fa61667d67ca2504f2e6d734843f5951fdaa28d834f2
#   Stored in directory: /Users/madhavsrivastava/Library/Caches/pip/wheels/23/9d/42/5ec745cbbb17517000a53cecc49d6a865450d1f5cb16dc8a9c
# Successfully built sklearn
# Installing collected packages: threadpoolctl, joblib, scipy, scikit-learn, sklearn
# Successfully installed joblib-0.17.0 scikit-learn-0.23.2 scipy-1.5.4 sklearn-0.0 threadpoolctl-2.1.0

# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts
import numpy as np

# %%
# Import data
ufc_data = pd.read_csv("data_files/ufc&event_info.csv")
ufc_data
# Out:
#      Unnamed: 0  Event ID        Date       Short Name  \
# 0             0       105  2020-02-08          UFC 247
# 1             1       105  2020-02-08          UFC 247
# 2             2       105  2020-02-08          UFC 247
# 3             3       105  2020-02-08          UFC 247
# 4             4       105  2020-02-08          UFC 247
# ..          ...       ...         ...              ...
# 363         363       162  2020-11-07  UFC Fight Night
# 364         364       162  2020-11-07  UFC Fight Night
# 365         365       162  2020-11-07  UFC Fight Night
# 366         366       162  2020-11-07  UFC Fight Night
# 367         367       162  2020-11-07  UFC Fight Night
#
#                                      Name            Date Time  \
# 0                UFC 247: Jones vs. Reyes  2020-02-08T18:30:00
# 1                UFC 247: Jones vs. Reyes  2020-02-08T18:30:00
# 2                UFC 247: Jones vs. Reyes  2020-02-08T18:30:00
# 3                UFC 247: Jones vs. Reyes  2020-02-08T18:30:00
# 4                UFC 247: Jones vs. Reyes  2020-02-08T18:30:00
# ..                                    ...                  ...
# 363  UFC Fight Night: Santos vs. Teixeira  2020-11-07T19:30:00
# 364  UFC Fight Night: Santos vs. Teixeira  2020-11-07T19:30:00
# 365  UFC Fight Night: Santos vs. Teixeira  2020-11-07T19:30:00
# 366  UFC Fight Night: Santos vs. Teixeira  2020-11-07T19:30:00
# 367  UFC Fight Night: Santos vs. Teixeira  2020-11-07T19:30:00
#
#          Red Fighter Name       Blue Fighter Name  \
# 0               Jon Jones          Dominick Reyes
# 1    Valentina Shevchenko       Katlyn Chookagian
# 2              Juan Adams             Justin Tafa
# 3           Mirsad Bektic                 Dan Ige
# 4           Derrick Lewis             Ilir Latifi
# ..                    ...                     ...
# 363         Giga Chikadze           Jamey Simmons
# 364      Alexandr Romanov  Marcos Rogerio de Lima
# 365         Darren Elkins       Eduardo Garagorri
# 366           Max Griffin          Ramiz Brahimaj
# 367         Gustavo Lopez         Anthony Birchak
#
#      American Odd that Red Fighter Will Win  \
# 0                                    -460.0
# 1                                    -920.0
# 2                                    -240.0
# 3                                    -125.0
# 4                                    -225.0
# ..                                      ...
# 363                                  -835.0
# 364                                  -455.0
# 365                                  -240.0
# 366                                  -143.0
# 367                                  -134.0
#
#      American Odd that Blue Fighter Will Win  ...  \
# 0                                      365.0  ...
# 1                                      610.0  ...
# 2                                      200.0  ...
# 3                                      105.0  ...
# 4                                      185.0  ...
# ..                                       ...  ...
# 363                                    525.0  ...
# 364                                    330.0  ...
# 365                                    185.0  ...
# 366                                    115.0  ...
# 367                                    108.0  ...
#
#     Blue Significant Strikes Landed/min Blue Significant Striking Accuracy  \
# 0                                  5.03                               0.52
# 1                                  4.35                               0.32
# 2                                  2.77                               0.66
# 3                                  4.15                               0.49
# 4                                  2.29                               0.40
# ..                                  ...                                ...
# 363                                0.00                               0.00
# 364                                3.78                               0.54
# 365                                3.75                               0.54
# 366                                0.00                               0.00
# 367                                3.98                               0.35
#
#     Blue Average Submissions Attempted/15min  \
# 0                                        0.4
# 1                                        0.1
# 2                                        0.0
# 3                                        1.0
# 4                                        0.5
# ..                                       ...
# 363                                      0.0
# 364                                      0.8
# 365                                      0.0
# 366                                      0.0
# 367                                      0.0
#
#      Blue Average Takedowns Landed/15min Blue Takedown Accuracy  \
# 0                                   0.39                   0.16
# 1                                   0.00                   0.00
# 2                                   0.00                   0.00
# 3                                   2.73                   0.34
# 4                                   1.85                   0.30
# ..                                   ...                    ...
# 363                                 0.00                   0.00
# 364                                 0.76                   0.60
# 365                                 0.79                   1.00
# 366                                 0.00                   0.00
# 367                                 0.68                   0.16
#
#      Red Significant Strikes Landed/min  Red Significant Striking Accuracy  \
# 0                                  4.31                               0.57
# 1                                  3.02                               0.49
# 2                                  7.32                               0.55
# 3                                  2.88                               0.42
# 4                                  2.63                               0.49
# ..                                  ...                                ...
# 363                                3.52                               0.43
# 364                                5.87                               0.37
# 365                                3.54                               0.37
# 366                                3.87                               0.49
# 367                                0.93                               0.24
#
#      Red Average Submissions Attempted/15min  \
# 0                                        0.5
# 1                                        0.4
# 2                                        0.0
# 3                                        0.4
# 4                                        0.0
# ..                                       ...
# 363                                      0.0
# 364                                      3.2
# 365                                      1.2
# 366                                      0.5
# 367                                      0.0
#
#      Red Average Takedowns Landed/15min  Red Takedown Accuracy
# 0                                  1.90                   0.46
# 1                                  1.94                   0.51
# 2                                  0.97                   0.66
# 3                                  3.38                   0.53
# 4                                  0.52                   0.25
# ..                                  ...                    ...
# 363                                0.40                   0.40
# 364                                6.41                   1.00
# 365                                2.43                   0.33
# 366                                1.90                   0.55
# 367                                0.00                   0.00
#
# [368 rows x 26 columns]
