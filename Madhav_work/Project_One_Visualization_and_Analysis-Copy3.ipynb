# %% [markdown]
# # PART 2: Data Visualization and Analysis

# %%
#!python -m pip install -U pip
#!python -m pip install -U matplotlib
#!python -m pip install -U sklearn

# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts
import numpy as np

# %% [markdown]
# ## Working with UFC&Event Data

# %%
# Import data
ufc_event_data = pd.read_csv("data_files/ufc&event_info.csv")
ufc_event_data
# Out:
#      Unnamed: 0  Event ID        Date       Short Name  \
# 0             0       105  2020-02-08          UFC 247
# 1             1       105  2020-02-08          UFC 247
# 2             2       105  2020-02-08          UFC 247
# 3             3       105  2020-02-08          UFC 247
# 4             4       105  2020-02-08          UFC 247
# ..          ...       ...         ...              ...
# 363         363       162  2020-11-07  UFC Fight Night
# 364         364       162  2020-11-07  UFC Fight Night
# 365         365       162  2020-11-07  UFC Fight Night
# 366         366       162  2020-11-07  UFC Fight Night
# 367         367       162  2020-11-07  UFC Fight Night
#
#                                      Name            Date Time  \
# 0                UFC 247: Jones vs. Reyes  2020-02-08T18:30:00
# 1                UFC 247: Jones vs. Reyes  2020-02-08T18:30:00
# 2                UFC 247: Jones vs. Reyes  2020-02-08T18:30:00
# 3                UFC 247: Jones vs. Reyes  2020-02-08T18:30:00
# 4                UFC 247: Jones vs. Reyes  2020-02-08T18:30:00
# ..                                    ...                  ...
# 363  UFC Fight Night: Santos vs. Teixeira  2020-11-07T19:30:00
# 364  UFC Fight Night: Santos vs. Teixeira  2020-11-07T19:30:00
# 365  UFC Fight Night: Santos vs. Teixeira  2020-11-07T19:30:00
# 366  UFC Fight Night: Santos vs. Teixeira  2020-11-07T19:30:00
# 367  UFC Fight Night: Santos vs. Teixeira  2020-11-07T19:30:00
#
#          Red Fighter Name       Blue Fighter Name  \
# 0               Jon Jones          Dominick Reyes
# 1    Valentina Shevchenko       Katlyn Chookagian
# 2              Juan Adams             Justin Tafa
# 3           Mirsad Bektic                 Dan Ige
# 4           Derrick Lewis             Ilir Latifi
# ..                    ...                     ...
# 363         Giga Chikadze           Jamey Simmons
# 364      Alexandr Romanov  Marcos Rogerio de Lima
# 365         Darren Elkins       Eduardo Garagorri
# 366           Max Griffin          Ramiz Brahimaj
# 367         Gustavo Lopez         Anthony Birchak
#
#      American Odd that Red Fighter Will Win  \
# 0                                    -460.0
# 1                                    -920.0
# 2                                    -240.0
# 3                                    -125.0
# 4                                    -225.0
# ..                                      ...
# 363                                  -835.0
# 364                                  -455.0
# 365                                  -240.0
# 366                                  -143.0
# 367                                  -134.0
#
#      American Odd that Blue Fighter Will Win  ...  \
# 0                                      365.0  ...
# 1                                      610.0  ...
# 2                                      200.0  ...
# 3                                      105.0  ...
# 4                                      185.0  ...
# ..                                       ...  ...
# 363                                    525.0  ...
# 364                                    330.0  ...
# 365                                    185.0  ...
# 366                                    115.0  ...
# 367                                    108.0  ...
#
#     Blue Significant Strikes Landed/min Blue Significant Striking Accuracy  \
# 0                                  5.03                               0.52
# 1                                  4.35                               0.32
# 2                                  2.77                               0.66
# 3                                  4.15                               0.49
# 4                                  2.29                               0.40
# ..                                  ...                                ...
# 363                                0.00                               0.00
# 364                                3.78                               0.54
# 365                                3.75                               0.54
# 366                                0.00                               0.00
# 367                                3.98                               0.35
#
#     Blue Average Submissions Attempted/15min  \
# 0                                        0.4
# 1                                        0.1
# 2                                        0.0
# 3                                        1.0
# 4                                        0.5
# ..                                       ...
# 363                                      0.0
# 364                                      0.8
# 365                                      0.0
# 366                                      0.0
# 367                                      0.0
#
#      Blue Average Takedowns Landed/15min Blue Takedown Accuracy  \
# 0                                   0.39                   0.16
# 1                                   0.00                   0.00
# 2                                   0.00                   0.00
# 3                                   2.73                   0.34
# 4                                   1.85                   0.30
# ..                                   ...                    ...
# 363                                 0.00                   0.00
# 364                                 0.76                   0.60
# 365                                 0.79                   1.00
# 366                                 0.00                   0.00
# 367                                 0.68                   0.16
#
#      Red Significant Strikes Landed/min  Red Significant Striking Accuracy  \
# 0                                  4.31                               0.57
# 1                                  3.02                               0.49
# 2                                  7.32                               0.55
# 3                                  2.88                               0.42
# 4                                  2.63                               0.49
# ..                                  ...                                ...
# 363                                3.52                               0.43
# 364                                5.87                               0.37
# 365                                3.54                               0.37
# 366                                3.87                               0.49
# 367                                0.93                               0.24
#
#      Red Average Submissions Attempted/15min  \
# 0                                        0.5
# 1                                        0.4
# 2                                        0.0
# 3                                        0.4
# 4                                        0.0
# ..                                       ...
# 363                                      0.0
# 364                                      3.2
# 365                                      1.2
# 366                                      0.5
# 367                                      0.0
#
#      Red Average Takedowns Landed/15min  Red Takedown Accuracy
# 0                                  1.90                   0.46
# 1                                  1.94                   0.51
# 2                                  0.97                   0.66
# 3                                  3.38                   0.53
# 4                                  0.52                   0.25
# ..                                  ...                    ...
# 363                                0.40                   0.40
# 364                                6.41                   1.00
# 365                                2.43                   0.33
# 366                                1.90                   0.55
# 367                                0.00                   0.00
#
# [368 rows x 26 columns]

# %%
# 2020/7/11, event id 121, first match day with COVID
# Remove unnecessary column
del ufc_event_data["Unnamed: 0"]

# %%
# Create a new column to hold pre/during COVID label
ufc_event_data["Pre/During COVID"] = ""
# Move it to the front
column_name = "Pre/During COVID"
first_column = ufc_event_data.pop(column_name)
ufc_event_data.insert(0,column_name,first_column)
ufc_event_data.head()
# Out:
#   Pre/During COVID  Event ID        Date Short Name                      Name  \
# 0                        105  2020-02-08    UFC 247  UFC 247: Jones vs. Reyes
# 1                        105  2020-02-08    UFC 247  UFC 247: Jones vs. Reyes
# 2                        105  2020-02-08    UFC 247  UFC 247: Jones vs. Reyes
# 3                        105  2020-02-08    UFC 247  UFC 247: Jones vs. Reyes
# 4                        105  2020-02-08    UFC 247  UFC 247: Jones vs. Reyes
#
#              Date Time      Red Fighter Name  Blue Fighter Name  \
# 0  2020-02-08T18:30:00             Jon Jones     Dominick Reyes
# 1  2020-02-08T18:30:00  Valentina Shevchenko  Katlyn Chookagian
# 2  2020-02-08T18:30:00            Juan Adams        Justin Tafa
# 3  2020-02-08T18:30:00         Mirsad Bektic            Dan Ige
# 4  2020-02-08T18:30:00         Derrick Lewis        Ilir Latifi
#
#    American Odd that Red Fighter Will Win  \
# 0                                  -460.0
# 1                                  -920.0
# 2                                  -240.0
# 3                                  -125.0
# 4                                  -225.0
#
#    American Odd that Blue Fighter Will Win  ...  \
# 0                                    365.0  ...
# 1                                    610.0  ...
# 2                                    200.0  ...
# 3                                    105.0  ...
# 4                                    185.0  ...
#
#   Blue Significant Strikes Landed/min Blue Significant Striking Accuracy  \
# 0                                5.03                               0.52
# 1                                4.35                               0.32
# 2                                2.77                               0.66
# 3                                4.15                               0.49
# 4                                2.29                               0.40
#
#   Blue Average Submissions Attempted/15min  \
# 0                                      0.4
# 1                                      0.1
# 2                                      0.0
# 3                                      1.0
# 4                                      0.5
#
#    Blue Average Takedowns Landed/15min Blue Takedown Accuracy  \
# 0                                 0.39                   0.16
# 1                                 0.00                   0.00
# 2                                 0.00                   0.00
# 3                                 2.73                   0.34
# 4                                 1.85                   0.30
#
#    Red Significant Strikes Landed/min  Red Significant Striking Accuracy  \
# 0                                4.31                               0.57
# 1                                3.02                               0.49
# 2                                7.32                               0.55
# 3                                2.88                               0.42
# 4                                2.63                               0.49
#
#    Red Average Submissions Attempted/15min  \
# 0                                      0.5
# 1                                      0.4
# 2                                      0.0
# 3                                      0.4
# 4                                      0.0
#
#    Red Average Takedowns Landed/15min  Red Takedown Accuracy
# 0                                1.90                   0.46
# 1                                1.94                   0.51
# 2                                0.97                   0.66
# 3                                3.38                   0.53
# 4                                0.52                   0.25
#
# [5 rows x 26 columns]

# %%
# Display the list of dates
ufc_event_data["Date"].unique()
# Out:
# array(['2020-02-08', '2020-02-15', '2020-02-22', '2020-02-29',
#        '2020-03-07', '2020-03-14', '2020-05-09', '2020-05-13',
#        '2020-05-16', '2020-05-30', '2020-06-06', '2020-06-13',
#        '2020-06-20', '2020-06-27', '2020-07-11', '2020-07-15',
#        '2020-07-18', '2020-07-25', '2020-08-01', '2020-08-08',
#        '2020-08-15', '2020-08-22', '2020-08-29', '2020-09-05',
#        '2020-09-12', '2020-09-19', '2020-09-26', '2020-10-03',
#        '2020-10-10', '2020-10-17', '2020-10-24', '2020-10-31',
#        '2020-11-07'], dtype=object)

# %%
# Identify the location of 2020-07-11
rowindex = ufc_event_data.index[ufc_event_data["Date"]=='2020-07-11']
rowindex
# Out:
# Int64Index([160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172], dtype='int64')

# %%
# Label the date before 2020-07-11 with "Pre_COVID" in Pre/During COVID column
# Label the date from 2020-07-11 on with "During_COVID" in Pre/During COVID column
rowrange = list(range(159))
rowduring = list(range(160,368))
ufc_event_data.loc[rowrange, "Pre/During COVID"] = "Pre_COVID"
ufc_event_data.loc[rowduring, "Pre/During COVID"] = "During_COVID"
ufc_event_data
# Out:
#     Pre/During COVID  Event ID        Date       Short Name  \
# 0          Pre_COVID       105  2020-02-08          UFC 247
# 1          Pre_COVID       105  2020-02-08          UFC 247
# 2          Pre_COVID       105  2020-02-08          UFC 247
# 3          Pre_COVID       105  2020-02-08          UFC 247
# 4          Pre_COVID       105  2020-02-08          UFC 247
# ..               ...       ...         ...              ...
# 363     During_COVID       162  2020-11-07  UFC Fight Night
# 364     During_COVID       162  2020-11-07  UFC Fight Night
# 365     During_COVID       162  2020-11-07  UFC Fight Night
# 366     During_COVID       162  2020-11-07  UFC Fight Night
# 367     During_COVID       162  2020-11-07  UFC Fight Night
#
#                                      Name            Date Time  \
# 0                UFC 247: Jones vs. Reyes  2020-02-08T18:30:00
# 1                UFC 247: Jones vs. Reyes  2020-02-08T18:30:00
# 2                UFC 247: Jones vs. Reyes  2020-02-08T18:30:00
# 3                UFC 247: Jones vs. Reyes  2020-02-08T18:30:00
# 4                UFC 247: Jones vs. Reyes  2020-02-08T18:30:00
# ..                                    ...                  ...
# 363  UFC Fight Night: Santos vs. Teixeira  2020-11-07T19:30:00
# 364  UFC Fight Night: Santos vs. Teixeira  2020-11-07T19:30:00
# 365  UFC Fight Night: Santos vs. Teixeira  2020-11-07T19:30:00
# 366  UFC Fight Night: Santos vs. Teixeira  2020-11-07T19:30:00
# 367  UFC Fight Night: Santos vs. Teixeira  2020-11-07T19:30:00
#
#          Red Fighter Name       Blue Fighter Name  \
# 0               Jon Jones          Dominick Reyes
# 1    Valentina Shevchenko       Katlyn Chookagian
# 2              Juan Adams             Justin Tafa
# 3           Mirsad Bektic                 Dan Ige
# 4           Derrick Lewis             Ilir Latifi
# ..                    ...                     ...
# 363         Giga Chikadze           Jamey Simmons
# 364      Alexandr Romanov  Marcos Rogerio de Lima
# 365         Darren Elkins       Eduardo Garagorri
# 366           Max Griffin          Ramiz Brahimaj
# 367         Gustavo Lopez         Anthony Birchak
#
#      American Odd that Red Fighter Will Win  \
# 0                                    -460.0
# 1                                    -920.0
# 2                                    -240.0
# 3                                    -125.0
# 4                                    -225.0
# ..                                      ...
# 363                                  -835.0
# 364                                  -455.0
# 365                                  -240.0
# 366                                  -143.0
# 367                                  -134.0
#
#      American Odd that Blue Fighter Will Win  ...  \
# 0                                      365.0  ...
# 1                                      610.0  ...
# 2                                      200.0  ...
# 3                                      105.0  ...
# 4                                      185.0  ...
# ..                                       ...  ...
# 363                                    525.0  ...
# 364                                    330.0  ...
# 365                                    185.0  ...
# 366                                    115.0  ...
# 367                                    108.0  ...
#
#     Blue Significant Strikes Landed/min Blue Significant Striking Accuracy  \
# 0                                  5.03                               0.52
# 1                                  4.35                               0.32
# 2                                  2.77                               0.66
# 3                                  4.15                               0.49
# 4                                  2.29                               0.40
# ..                                  ...                                ...
# 363                                0.00                               0.00
# 364                                3.78                               0.54
# 365                                3.75                               0.54
# 366                                0.00                               0.00
# 367                                3.98                               0.35
#
#     Blue Average Submissions Attempted/15min  \
# 0                                        0.4
# 1                                        0.1
# 2                                        0.0
# 3                                        1.0
# 4                                        0.5
# ..                                       ...
# 363                                      0.0
# 364                                      0.8
# 365                                      0.0
# 366                                      0.0
# 367                                      0.0
#
#      Blue Average Takedowns Landed/15min Blue Takedown Accuracy  \
# 0                                   0.39                   0.16
# 1                                   0.00                   0.00
# 2                                   0.00                   0.00
# 3                                   2.73                   0.34
# 4                                   1.85                   0.30
# ..                                   ...                    ...
# 363                                 0.00                   0.00
# 364                                 0.76                   0.60
# 365                                 0.79                   1.00
# 366                                 0.00                   0.00
# 367                                 0.68                   0.16
#
#      Red Significant Strikes Landed/min  Red Significant Striking Accuracy  \
# 0                                  4.31                               0.57
# 1                                  3.02                               0.49
# 2                                  7.32                               0.55
# 3                                  2.88                               0.42
# 4                                  2.63                               0.49
# ..                                  ...                                ...
# 363                                3.52                               0.43
# 364                                5.87                               0.37
# 365                                3.54                               0.37
# 366                                3.87                               0.49
# 367                                0.93                               0.24
#
#      Red Average Submissions Attempted/15min  \
# 0                                        0.5
# 1                                        0.4
# 2                                        0.0
# 3                                        0.4
# 4                                        0.0
# ..                                       ...
# 363                                      0.0
# 364                                      3.2
# 365                                      1.2
# 366                                      0.5
# 367                                      0.0
#
#      Red Average Takedowns Landed/15min  Red Takedown Accuracy
# 0                                  1.90                   0.46
# 1                                  1.94                   0.51
# 2                                  0.97                   0.66
# 3                                  3.38                   0.53
# 4                                  0.52                   0.25
# ..                                  ...                    ...
# 363                                0.40                   0.40
# 364                                6.41                   1.00
# 365                                2.43                   0.33
# 366                                1.90                   0.55
# 367                                0.00                   0.00
#
# [368 rows x 26 columns]

# %% [markdown]
# ## Working with UFC Results Data

# %%
# Import data
ufc_result_data = pd.read_csv("data_files/UFC2020FightResults.csv")
ufc_result_data
# Out:
#        Unnamed: 0  W/L               FIGHTER KD  STR TD SUB  \
# 0       Pre_COVID  WIN             Jon Jones  0  104  2   0
# 1       Pre_COVID  NaN        Dominick Reyes  0  116  0   0
# 2       Pre_COVID  WIN  Valentina Shevchenko  0   40  3   0
# 3       Pre_COVID  NaN     Katlyn Chookagian  0   17  0   0
# 4       Pre_COVID  WIN           Justin Tafa  1   10  0   0
# ..            ...  ...                   ... ..  ... ..  ..
# 758  During_COVID  NaN    Geraldo de Freitas  0   76  1   0
# 759  During_COVID  WIN           Alex Morono  0  176  3   0
# 760  During_COVID  NaN            Rhys McKee  0  124  0   0
# 761  During_COVID  WIN        Don'Tale Mayes  0   59  1   0
# 762  During_COVID  NaN        Roque Martinez  0   58  1   0
#
#           WEIGHT CLASS   METHOD ROUND  TIME
# 0    Light Heavyweight    U-DEC     5  5:00
# 1                  NaN      NaN   NaN   NaN
# 2    Women's Flyweight   KO/TKO     3  1:03
# 3                  NaN  Punches   NaN   NaN
# 4          Heavyweight   KO/TKO     1  1:59
# ..                 ...      ...   ...   ...
# 758                NaN      NaN   NaN   NaN
# 759       Welterweight    U-DEC     3  5:00
# 760                NaN      NaN   NaN   NaN
# 761        Heavyweight    U-DEC     3  5:00
# 762                NaN      NaN   NaN   NaN
#
# [763 rows x 11 columns]

# %%
renamed_reuslt = ufc_result_data.rename(columns={"Unnamed: 0":"Pre/During COVID"})
renamed_reuslt
# Out:
#     Pre/During COVID  W/L               FIGHTER KD  STR TD SUB  \
# 0          Pre_COVID  WIN             Jon Jones  0  104  2   0
# 1          Pre_COVID  NaN        Dominick Reyes  0  116  0   0
# 2          Pre_COVID  WIN  Valentina Shevchenko  0   40  3   0
# 3          Pre_COVID  NaN     Katlyn Chookagian  0   17  0   0
# 4          Pre_COVID  WIN           Justin Tafa  1   10  0   0
# ..               ...  ...                   ... ..  ... ..  ..
# 758     During_COVID  NaN    Geraldo de Freitas  0   76  1   0
# 759     During_COVID  WIN           Alex Morono  0  176  3   0
# 760     During_COVID  NaN            Rhys McKee  0  124  0   0
# 761     During_COVID  WIN        Don'Tale Mayes  0   59  1   0
# 762     During_COVID  NaN        Roque Martinez  0   58  1   0
#
#           WEIGHT CLASS   METHOD ROUND  TIME
# 0    Light Heavyweight    U-DEC     5  5:00
# 1                  NaN      NaN   NaN   NaN
# 2    Women's Flyweight   KO/TKO     3  1:03
# 3                  NaN  Punches   NaN   NaN
# 4          Heavyweight   KO/TKO     1  1:59
# ..                 ...      ...   ...   ...
# 758                NaN      NaN   NaN   NaN
# 759       Welterweight    U-DEC     3  5:00
# 760                NaN      NaN   NaN   NaN
# 761        Heavyweight    U-DEC     3  5:00
# 762                NaN      NaN   NaN   NaN
#
# [763 rows x 11 columns]

# %%
pre_covid_groupby = renamed_reuslt.loc[renamed_reuslt["Pre/During COVID"]=="Pre_COVID"]
pre_covid_groupby
# Out:
#     Pre/During COVID  W/L               FIGHTER KD  STR TD SUB  \
# 0          Pre_COVID  WIN             Jon Jones  0  104  2   0
# 1          Pre_COVID  NaN        Dominick Reyes  0  116  0   0
# 2          Pre_COVID  WIN  Valentina Shevchenko  0   40  3   0
# 3          Pre_COVID  NaN     Katlyn Chookagian  0   17  0   0
# 4          Pre_COVID  WIN           Justin Tafa  1   10  0   0
# ..               ...  ...                   ... ..  ... ..  ..
# 313        Pre_COVID  NaN          Philipe Lins  0    6  0   0
# 314        Pre_COVID  WIN            Kay Hansen  0   31  2   1
# 315        Pre_COVID  NaN          Jinh Yu Frey  0   26  0   0
# 316        Pre_COVID  WIN         Youssef Zalal  0   59  0   0
# 317        Pre_COVID  NaN        Jordan Griffin  0   28  2   0
#
#             WEIGHT CLASS   METHOD ROUND  TIME
# 0      Light Heavyweight    U-DEC     5  5:00
# 1                    NaN      NaN   NaN   NaN
# 2      Women's Flyweight   KO/TKO     3  1:03
# 3                    NaN  Punches   NaN   NaN
# 4            Heavyweight   KO/TKO     1  1:59
# ..                   ...      ...   ...   ...
# 313                  NaN  Punches   NaN   NaN
# 314  Women's Strawweight      SUB     3  2:26
# 315                  NaN   Armbar   NaN   NaN
# 316        Featherweight    U-DEC     3  5:00
# 317                  NaN      NaN   NaN   NaN
#
# [318 rows x 11 columns]

# %%
groupby_method = pre_covid_groupby.groupby("METHOD")["Pre/During COVID"].count()
groupby_method
# Out:
# METHOD
# Ankle Lock           1
# Arm Triangle         3
# Armbar               3
# D'Arce Choke         1
# DQ                   2
# Elbow                2
# Flying Knee          1
# Guillotine Choke     5
# KO/TKO              49
# Kick                 2
# Kimura               1
# Knee                 2
# Kneebar              1
# Knees                1
# M-DEC                1
# Overturned           1
# Punch               22
# Punches             19
# Rear Naked Choke    10
# S-DEC               19
# SUB                 25
# U-DEC               62
# Name: Pre/During COVID, dtype: int64

# %%
x_axis = ["KO/TKO","U-DEC","S-DEC","SUB" ]
pre_covid = [49,62,19,25]

# %%
during_covid_groupby = renamed_reuslt.loc[renamed_reuslt["Pre/During COVID"]=="During_COVID"]
during_covid_groupby
# Out:
#     Pre/During COVID  W/L                FIGHTER KD  STR TD SUB  \
# 319     During_COVID  WIN           Kamaru Usman  0   94  5   0
# 320     During_COVID  NaN         Jorge Masvidal  0   66  0   0
# 321     During_COVID  WIN  Alexander Volkanovski  0  137  3   0
# 322     During_COVID  NaN           Max Holloway  0  102  0   0
# 323     During_COVID  WIN               Petr Yan  1  194  1   0
# ..               ...  ...                    ... ..  ... ..  ..
# 758     During_COVID  NaN     Geraldo de Freitas  0   76  1   0
# 759     During_COVID  WIN            Alex Morono  0  176  3   0
# 760     During_COVID  NaN             Rhys McKee  0  124  0   0
# 761     During_COVID  WIN         Don'Tale Mayes  0   59  1   0
# 762     During_COVID  NaN         Roque Martinez  0   58  1   0
#
#       WEIGHT CLASS  METHOD ROUND  TIME
# 319   Welterweight   U-DEC     5  5:00
# 320            NaN     NaN   NaN   NaN
# 321  Featherweight   S-DEC     5  5:00
# 322            NaN     NaN   NaN   NaN
# 323   Bantamweight  KO/TKO     5  3:24
# ..             ...     ...   ...   ...
# 758            NaN     NaN   NaN   NaN
# 759   Welterweight   U-DEC     3  5:00
# 760            NaN     NaN   NaN   NaN
# 761    Heavyweight   U-DEC     3  5:00
# 762            NaN     NaN   NaN   NaN
#
# [444 rows x 11 columns]

# %%
during_method = during_covid_groupby.groupby("METHOD")["Pre/During COVID"].count()
during_method
# Out:
# METHOD
# Anaconda Choke         1
# Arm Triangle           2
# Armbar                10
# D'Arce Choke           1
# Elbow                  2
# Elbows                 4
# Forearm Choke          1
# Guillotine Choke      10
# Heel Hook              1
# Injury                 1
# KO/TKO                67
# Kick                   8
# Kimura                 1
# Knee                   4
# Kneebar                1
# M-DEC                  2
# Neck Crank             1
# Overturned             2
# Punch                 20
# Punches               24
# Rear Naked Choke      14
# S-DEC                 16
# SUB                   46
# Spinning Back Fist     1
# Spinning Back Kick     1
# Triangle Choke         3
# U-DEC                 89
# Name: Pre/During COVID, dtype: int64
